# %% [markdown]
# Pillow Tutorial
#
# https://pillow.readthedocs.io/en/stable/handbook/tutorial.html
#
# Matplotlib Image Tutorial
#
# https://matplotlib.org/tutorials/introductory/images.html

# %%
from PIL import Image
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %% [markdown]
# ## Using the Image Class

# %%
im = Image.open("interesting_giraffe.jpg")

# %%
print(im.format, im.size, im.mode)
# Out:
# JPEG (630, 355) RGB

# %%
im.show()

# %% [markdown]
# ## Reading and writing images

# %% [markdown]
# This script assumes you are not running it in a notebook.
#
# It is intended to be run from the command line.

# %%
# Converting files to JPEG

import os, sys
from PIL import Image

print(sys.argv[1:])

for infile in sys.argv[1:]:
    f, e = os.path.splitext(infile)
    outfile = f + ".jpg"
    if infile != outfile:
        try:
            with Image.open(infile) as im:
                im.save(outfile)
        except OSError:
            print("cannot convert", infile)
# Out:
# ['-f', '/home/frostburn/.local/share/jupyter/runtime/kernel-3dc01dcf-8fb1-4bdf-9f74-5bec1b5d660e.json']
# cannot convert -f
# cannot convert /home/frostburn/.local/share/jupyter/runtime/kernel-3dc01dcf-8fb1-4bdf-9f74-5bec1b5d660e.json

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
img = mpimg.imread("interesting_giraffe.jpg")

# %%
img.shape
# Out:
# (355, 630, 3)

# %%
img
# Out:
# array([[[215, 218, 201],
#         [215, 218, 201],
#         [216, 219, 202],
#         ...,
#         [ 91, 189, 216],
#         [ 91, 189, 216],
#         [ 91, 189, 216]],
#
#        [[215, 218, 201],
#         [215, 218, 201],
#         [216, 219, 202],
#         ...,
#         [ 91, 189, 216],
#         [ 91, 189, 216],
#         [ 91, 189, 216]],
#
#        [[216, 219, 202],
#         [216, 219, 202],
#         [216, 219, 202],
#         ...,
#         [ 90, 188, 215],
#         [ 90, 188, 215],
#         [ 90, 188, 215]],
#
#        ...,
#
#        [[201, 204, 183],
#         [196, 198, 177],
#         [196, 195, 175],
#         ...,
#         [194, 205, 201],
#         [197, 208, 204],
#         [192, 203, 199]],
#
#        [[195, 198, 177],
#         [196, 198, 177],
#         [203, 202, 182],
#         ...,
#         [194, 205, 201],
#         [197, 208, 204],
#         [192, 203, 199]],
#
#        [[202, 205, 184],
#         [196, 198, 177],
#         [196, 195, 175],
# ...

# %%
plt.imshow(img)

# %%
plt.imshow(img[50:280,330:550,:])
